# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaed58c092823e4a9c72303930363033.html'

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

soup.find('table')
soup.find_all('table')

soup.find('table', class_ = 'table')
table = soup.find_all('table')

world_titles = soup.find_all('td', class_ = 'text-right')
world_table_titles = [title.text.strip() for title in world_titles]

rd = pd.DataFrame(columns = world_table_titles)
column_data = soup.find_all('tr')

kolom_data = [[] for _ in range(19)]

for row in column_data[1:19]:
    
    row_data = row.find_all('td')

    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

kolom_data = [kolom for kolom in kolom_data if kolom]


for kolom in kolom_data:
    print(kolom)

length = len(rd)
rd.loc[length] = kolom
rd
# Out:
# ['81/Pid.Sus/2022/PN Mjk', 'Pertama', 'Pidana Khusus  Narkotika dan Psikotropika', '', '2022', '6 April 2022', 'PN MOJOKERTO', 'PN', 'Ardiani', 'Syufrinaldi, B. M. Cintia Buana', 'Rahayuwati', 'Lain-lain', 'HUKUM', '- MENGADILIMenyatakan terdakwa SUSANTO alias YANTO Bin (Alm) SUKIRAN tidak terbukti secara sah dan meyakinkan bersalah melakukan tindak pidana sebagaimana dakwaan Primair Penuntut Umum;Membebaskan terdakwa SUSANTO alias YANTO Bin (Alm) SUKIRAN dari dakwaan Primair Penuntut Umum tersebut;Menyatakan terdakwa SUSANTO alias YANTO Bin (Alm) SUKIRAN terbukti secara sah dan meyakinkan bersalah melakukan tindak pidana ?tanpa hak menguasai Narkotika Golongan I bukan tanaman, sesuai dengan dakwaan Subsidair Penuntut Umum;Menjatuhkan pidana terhadap terdakwa SUSANTO alias YANTO Bin (Alm) SUKIRAN dengan pidana penjara selama 4 (empat) tahun dan denda sebesar Rp.800.000.000,00 (delapan ratus juta rupiah) dengan ketentuan apabila denda tersebut tidak dibayar maka diganti dengan pidana 
# ...

# %%
def get_data(url):
  page = requests.get(url)
  soup = BeautifulSoup(page.text, 'html')

  column_data = soup.find_all('tr')

  kolom_data = [[] for _ in range(19)]
  page = requests.get(url)
  soup = BeautifulSoup(page.text, 'html')

  column_data = soup.find_all('tr')

  kolom_data = [[] for _ in range(19)]

  for row in column_data[1:19]:
      row_data = row.find_all('td')

      for i, data in enumerate(row_data):
          if 'text-right' not in data.get('class', []):
              kolom_data[i].append(data.text.strip())

  kolom_data = [kolom for kolom in kolom_data if kolom]

  for kolom in kolom_data:
      print(kolom)

  length = len(rd)
  rd.loc[length] = kolom

# %%
urls = [
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaed58c092823e4a9c72303930363033.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaece894b987074ca75c313531303030.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaed6a1e03a4f8249d9f313132373436.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaedf2eece24b342be48313430343539.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaeda8ed9d10f5c28257303935303031.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaec8a4ba4026a3a9572313533303032.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaed58c33c027a3cbd0e303932353036.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee2a8dcc441a3c9939303835313430.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee55e0130d78e69397313135383537.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee2a8ad3152a8e8d45303833303233.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaedb2635036f808b196313034353133.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee2a8ad3152a8e8d45303833303233.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaedea4cec1139f2bda4313432363031.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaedea4d625ca8da8e97313432393230.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee25200b3a8b4a96c6313130333235.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee55df8d1684c68181313135353132.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaed6f986588673688e5313034363234.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/za
# 2   30/Pid.Sus/2022/PN Mjk        Pertama
# 3   96/Pid.Sus/2022/PN Mjk        Pertama
# 4  435/Pid.Sus/2022/PN Mjk        Pertama
#
#                                  Klasifikasi Kata Kunci Tahun  \
# 0  Pidana Khusus  Narkotika dan Psikotropika             2022
# 1  Pidana Khusus  Narkotika dan Psikotropika             2022
# 2  Pidana Khusus  Narkotika dan Psikotropika             2022
# 3  Pidana Khusus  Narkotika dan Psikotropika             2022
# 4  Pidana Khusus  Narkotika dan Psikotropika             2023
#
#    Tanggal Register Lembaga Peradilan Jenis Lembaga Peradilan    Hakim Ketua  \
# 0      6 April 2022      PN MOJOKERTO                      PN        Ardiani
# 1      6 April 2022      PN MOJOKERTO                      PN        Ardiani
# 2   26 Januari 2022      PN MOJOKERTO                      PN  Luqmanulhakim
# ...

# %%
rd.tail()
# Out:
#                       Nomor Tingkat Proses  \
# 57  194/Pid.Sus/2022/PN Mjk        Pertama
# 58  370/Pid.Sus/2022/PN Mjk        Pertama
# 59  399/Pid.Sus/2022/PN Mjk        Pertama
# 60  418/Pid.Sus/2022/PN Mjk        Pertama
# 61  390/Pid.Sus/2022/PN Mjk        Pertama
#
#                                   Klasifikasi Kata Kunci Tahun  \
# 57  Pidana Khusus  Narkotika dan Psikotropika             2022
# 58  Pidana Khusus  Narkotika dan Psikotropika             2022
# 59  Pidana Khusus  Narkotika dan Psikotropika             2023
# 60  Pidana Khusus  Narkotika dan Psikotropika             2023
# 61  Pidana Khusus  Narkotika dan Psikotropika             2022
#
#     Tanggal Register Lembaga Peradilan Jenis Lembaga Peradilan  \
# 57      29 Juni 2022      PN MOJOKERTO                      PN
# 58   10 Oktober 2022      PN MOJOKERTO                      PN
# 59   31 Oktober 2022      PN MOJOKERTO                      PN
# 60  10 Nopember 2022      PN MOJOKERTO                      PN
# ...

# %%
rd
# Out:
#                       Nomor Tingkat Proses  \
# 0    81/Pid.Sus/2022/PN Mjk        Pertama
# 1    81/Pid.Sus/2022/PN Mjk        Pertama
# 2    30/Pid.Sus/2022/PN Mjk        Pertama
# 3    96/Pid.Sus/2022/PN Mjk        Pertama
# 4   435/Pid.Sus/2022/PN Mjk        Pertama
# ..                      ...            ...
# 57  194/Pid.Sus/2022/PN Mjk        Pertama
# 58  370/Pid.Sus/2022/PN Mjk        Pertama
# 59  399/Pid.Sus/2022/PN Mjk        Pertama
# 60  418/Pid.Sus/2022/PN Mjk        Pertama
# 61  390/Pid.Sus/2022/PN Mjk        Pertama
#
#                                   Klasifikasi Kata Kunci Tahun  \
# 0   Pidana Khusus  Narkotika dan Psikotropika             2022
# 1   Pidana Khusus  Narkotika dan Psikotropika             2022
# 2   Pidana Khusus  Narkotika dan Psikotropika             2022
# 3   Pidana Khusus  Narkotika dan Psikotropika             2022
# 4   Pidana Khusus  Narkotika dan Psikotropika             2023
# ...

# %%
rd.to_csv('pn_mojokerto.csv')
